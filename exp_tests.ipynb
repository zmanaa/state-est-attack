# %%
import matplotlib.pyplot as plt
from matplotlib.gridspec import GridSpec

fig = plt.figure(figsize=(8, 6))
gs = GridSpec(nrows=2, ncols=2, figure=fig)

# Top row: two small panels
ax2 = fig.add_subplot(gs[0, 0])  # row 0, col 0
ax3 = fig.add_subplot(gs[0, 1])  # row 0, col 1

# Bottom row: one panel spanning both columns
ax1 = fig.add_subplot(gs[1, :])  # row 1, all columns

# Now plot as you like
ax2.plot(t1, f(t1))
ax2.set_title("Zoomed out")
ax3.plot(t1, f(t1))
ax3.set_title("Zoomed in")
ax1.plot(t1, f(t1))
ax1.margins(0.05)
plt.tight_layout()
